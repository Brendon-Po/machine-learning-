# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

# %%
from sklearn import datasets
iris = datasets.load_iris()

features = pd.DataFrame(data=iris.data, columns = iris.feature_names)
target = pd.DataFrame(data=iris.target, columns=['target'])
df = pd.concat([features, target], axis=1)


#multiplicando uma das features por 100 para visualizar o scaling
features['sepal width (cm)'] = features['sepal width (cm)'] * 100

# %%
clf = KNeighborsClassifier(n_neighbors=5)
# Out:
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

y_train = y_train.values.ravel()
y_test = y_test.values.ravel()

# %%
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
y_pred_train = clf.predict(X_train)

# %% [markdown]
# ## Acuracia

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[19,  0,  0],
#        [ 1,  8,  4],
#        [ 1,  3,  9]])

# %%
accuracy_score(y_train, y_pred_train)
# Out:
# 0.819047619047619

# %%
cm2 = confusion_matrix(y_train, y_pred_train)
cm2
# Out:
# array([[31,  0,  0],
#        [ 0, 33,  4],
#        [ 0,  1, 36]])

# %% [markdown]
# ## Com pipeline e standardscaler

# %%
ppl1 = Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsClassifier(n_neighbors=5)) ])
ppl1.fit(X_train, y_train)
y_pred_ppl1 = ppl1.predict(X_test)

# %%
accuracy_score(y_test, y_pred_ppl1)
# Out:
# 1.0

# %%
y_pred_ppl1_train = ppl1.predict(X_train)
accuracy_score(y_train, y_pred_ppl1_train)
# Out:
# 0.9523809523809523
